# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../datasets/data_titanic.csv")

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
null_values = df.isnull().sum()
null_values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
plt.figure(figsize=(20, 10))
sns.barplot(hue=null_values.index, y=null_values, palette="inferno", edgecolor="black")
plt.title("Missing Values")
plt.xlabel("Features")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df.drop("Cabin", axis=1, inplace=True)

# %%
df["Age"] = df["Age"].fillna(np.mean(df["Age"]))

# %%
df["Embarked"] = df["Embarked"].fillna(df["Embarked"].mode()[0])

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
survived = df["Survived"]

# %%
plt.figure(figsize=(20, 10))
sns.barplot(
    hue=df["Pclass"],
    y=df["Survived"],
    palette="inferno",
    edgecolor="white",
    err_kws={"color": "lightcoral"},
)
plt.title("Pclass vs Survived")
plt.xlabel("Pclass")
plt.ylabel("Fare")
# Out:
# Text(0, 0.5, 'Fare')

# %%
plt.figure(figsize=(20, 10))
sns.histplot(df, x="Age", hue="Survived", bins=10, kde=True, palette="inferno")
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize=(20, 10))
sns.lineplot(data=df, x=df.index, y="Fare", color="cyan")
plt.title("Line Plot of Fare over Passenger Index")
# Out:
# Text(0.5, 1.0, 'Line Plot of Fare over Passenger Index')

# %%
plt.figure(figsize=(20, 10))
sns.boxplot(data=df, x="Pclass", y="Age", color="cyan")
plt.title("Pclass vs Age")
# Out:
# Text(0.5, 1.0, 'Pclass vs Age')

# %%
plt.figure(figsize=(20, 10))
sns.scatterplot(
    data=df,
    x="Age",
    y="Fare",
    hue="Survived",
    edgecolor="black",
    palette=["cyan", "coral"],
)
plt.title("Age vs Fare")
# Out:
# Text(0.5, 1.0, 'Age vs Fare')

# %%
plt.figure(figsize=(20, 10))
sns.pointplot(x="Pclass", y="Survived", hue="Sex", data=df, palette=["cyan", "coral"])
plt.title("Survival Rate by Class and Gender")
plt.show()

# %%
# Count Plot: Survival by Sex
plt.figure(figsize=(16, 9))
sns.countplot(
    x="Sex",
    hue="Survived",
    data=df,
    palette=["cyan", "coral"],
    edgecolor="black",
)
plt.title("Survival Count by Sex")
# Out:
# Text(0.5, 1.0, 'Survival Count by Sex')

# %%
plt.figure(figsize=(20, 10))

sns.violinplot(
    x="Survived",
    y="Fare",
    hue="Sex",
    data=df,
    split=True,
    palette=["cyan", "coral"],
    edgecolor="black",
)
plt.title("Violin Plot: Fare Distribution by Class and Gender")
plt.show()

# %%
plt.figure(figsize=(20, 10))

sns.swarmplot(
    x="Pclass",
    y="Age",
    hue="Survived",
    data=df,
    palette=["cyan", "coral"],
    dodge=False,
    legend=False,
    size=2,
)
plt.title("Swarm Plot: Age distribution by Survival Status")
plt.show()

# %%
plt.figure(figsize=(20, 10))

sns.kdeplot(x=df["Age"], fill=True, color="cyan")
plt.title("KDE Plot: Age Distribution")
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.boxplot(
    data=df,
    x="Sex",
    y="Age",
    hue="Survived",
    palette=["cyan", "coral"],
)
plt.xlabel("Sex")
plt.ylabel("Age")
plt.title("Age vs Sex")
# Out:
# Text(0.5, 1.0, 'Age vs Sex')
